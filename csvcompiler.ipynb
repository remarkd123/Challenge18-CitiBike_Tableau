# %%
import os
from os import chdir
from glob import glob
import pandas as pd
import csv 
import numpy as np

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
file_to_load = "raw_data/summers/201907-citibike-tripdata.csv"
file_to_load2 = "raw_data/summers/202007-citibike-tripdata.csv"
file_to_load3 = "raw_data/summers/202107-citibike-tripdata.csv"
file_to_load4 = "raw_data/summers/202207-citibike-tripdata.csv"
citibike19_df = pd.read_csv(file_to_load)
citibike20_df = pd.read_csv(file_to_load2)
citibike21_df = pd.read_csv(file_to_load3)
citibike22_df = pd.read_csv(file_to_load4)
citibike19_df
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_1176\4008498761.py:8: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibike21_df = pd.read_csv(file_to_load3)
# C:\Users\David\AppData\Local\Temp\ipykernel_1176\4008498761.py:9: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibike22_df = pd.read_csv(file_to_load4)
#          tripduration                 starttime                  stoptime  \
# 0                 897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1                 267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2                2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3                1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4                 109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
# ...               ...                       ...                       ...
# ...

# %%
# 2. Check the datatypes of your columns. 
citibike21_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id      float64
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
citibike20_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
new_tripduration19 = citibike19_df.tripduration
new_tripduration20 = citibike20_df.tripduration
new_tripduration21 = citibike21_df.tripduration
new_tripduration22 = citibike22_df.tripduration

# print(new_tripduration)

new_tripduration_datetime19 = pd.to_datetime(new_tripduration19, unit='m')
new_tripduration_datetime20 = pd.to_datetime(new_tripduration20, unit='m')
new_tripduration_datetime21 = pd.to_datetime(new_tripduration21, unit='m')
new_tripduration_datetime22 = pd.to_datetime(new_tripduration22, unit='m')

# print(new_tripduration_datetime)

# Add a new column for the converted trip duration
citibike19_df['new_tripduration'] = new_tripduration_datetime19
citibike20_df['new_tripduration'] = new_tripduration_datetime20
citibike21_df['new_tripduration'] = new_tripduration_datetime21
citibike22_df['new_tripduration'] = new_tripduration_datetime22

# %%
# 4. Check the datatypes of your columns. 
# new tripduration shows as a datatime
citibike19_df.dtypes
# Out:
# tripduration                        int64
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# new_tripduration           datetime64[ns]
# dtype: object

# %%
merged_df = pd.merge(citibike19_df,citibike20_df, how='outer')
merged2_df = pd.merge(citibike21_df,citibike22_df, how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\workdocs\Repos\Challenge18-CitiBike_Tableau\csvcompiler.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/workdocs/Repos/Challenge18-CitiBike_Tableau/csvcompiler.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> merged_df = pd.merge(citibike19_df,citibike20_df, how='outer')
# ----> <a href='vscode-notebook-cell:/e%3A/workdocs/Repos/Challenge18-CitiBike_Tableau/csvcompiler.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> merged2_df = pd.merge(citibike21_df,citibike22_df, how='outer')
#
# File c:\Users\David\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
# ...

# %%
import os
import csv, glob

Dir = r"E:\workdocs\Repos\Challenge18-CitiBike_Tableau\raw_data\summers"
Out_Dir = r"E:\workdocs\Repos\Challenge18-CitiBike_Tableau\Resources"

csv_file_list = glob.glob(os.path.join(Dir, '*.csv'))
print (csv_file_list)
# Out:
# ['E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\201907-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\201908-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202007-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202008-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202107-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202108-citibike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202207-citbike-tripdata.csv', 'E:\\workdocs\\Repos\\Challenge18-CitiBike_Tableau\\raw_data\\summers\\202208-citibike-tripdata.csv']

# %%
pd.merge()

# %%
with open(os.path.join(Out_Dir, 'Output-summers.csv'), 'w', newline='') as f:
    wf = csv.writer(f, lineterminator='\n')

    for files in csv_file_list:
        with open(files, 'r') as r: 
            next(r)                   # SKIP HEADERS
            rr = csv.reader(r)
            for row in rr:
                wf.writerow(row)

# %%
target = "E:\workdocs\Repos\Challenge18-CitiBike_Tableau\Resources\Output-summers.csv"

books_df = pd.read_csv(target, encoding="utf-8")
books_df.head(10)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_1176\89230864.py:3: DtypeWarning: Columns (0,3,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv(target, encoding="utf-8")
#     897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040   493  \
# 0   267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500  3143
# 1  2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490   317
# 2  1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050   249
# 3   109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670  3552
# 4   106  2019-07-01 00:00:12.6680  2019-07-01 00:01:59.6060  3593
# 5   550  2019-07-01 00:00:14.4940  2019-07-01 00:09:25.3970  3507
# 6   338  2019-07-01 00:00:18.1350  2019-07-01 00:05:56.9780   478
# 7   469  2019-07-01 00:00:25.0940  2019-07-01 00:08:14.2420   514
# 8   562  2019-07-01 00:00:26.7780  2019-07-01 00:09:49.2100   116
# 9  2420  2019-07-01 00:00:29.6810  2019-07-01 00:40:49.8050  3054
#
# ...

# %%
renamed_df = books_df.rename(columns={"Trip Duration":'tripduration',
                                        "Start Time":'starttime',
                                        "Stop Time": 'stoptime',
                                        "Start Station ID": 'start station id',
                                        "Start Station Name":'start station name',
                                        'Start Station Latitude': 'start station latitude',
                                        'Start Station Longitude': 'start station longitude',
                                        'End Station ID': 'end station id',
                                        'End Station Name': 'end station name',
                                        'End Station Latitude': 'end station latitude',
                                        'End Station Longitude':'end station longitude',
                                        'Bike ID': 'bikeid',
                                        'User Type':'usertype', 
                                        'Birth Year': 'birth year',
                                        'Gender': 'gender',})

filename = "output-summers-clean.csv"

renamed_df.to_csv(filename,encoding="utf-8", index=False, header=True)
